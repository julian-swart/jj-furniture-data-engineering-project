# %% [markdown]
# # Create Fake Customers Data

# %% [raw]
# !pip install faker

# %%
import pandas as pd
import numpy as np
from faker import Faker
from sqlalchemy import create_engine
#import sql_queries as sql
import configparser
import sys 
import os

# %%
script_dir = os.path.abspath('')
mymodule_dir = os.path.join( script_dir, '..', '..', 'database', 'table_setup' )
sys.path.append( mymodule_dir )

import sql_queries

# %%
mymodule_dir = os.path.join( script_dir, '..', '..', 'database', 'connection' )
sys.path.append( mymodule_dir )

import postgres_db

# %%
# =============================================================================
# ### SQL CONNECTION
# =============================================================================
encoding = 'utf-16'

config_file_path = os.path.join( script_dir, '..', '..', 'database', 'connection' )
config_file_path += '/config.ini'

db_conn = postgres_db.PostgresConnector(config_file_path=config_file_path,
                                       section='jj_furniture',
                                       encoding=encoding)

# %%
fake = Faker()

# %%
store_type = ['Store', 'Web']
num_customers = 1000

customers = [
    {
     'first_name': fake.first_name(),
     'last_name': fake.last_name(),
     'email_address': fake.email(),
     'dob': fake.date_between(start_date='-70y', end_date='-18y'),
     'gender': fake.profile()['sex'],
     'street_address': fake.street_address(),
     'state': fake.random_element(elements = ('NC', 'SC', 'TN', 'FL', 'GA', 'MS', 'AL')),
     'date_created': fake.date_between(start_date='-12y'),
     'create_source': np.random.choice(store_type, p = [.8, .2]) # can give probability of selection to Store Type
    }
    for x in range(num_customers)]

# %%
df_customers = pd.DataFrame(customers)

# %%
df_customers.head()
# Out:
#   create_source date_created         dob         email_address first_name  \
# 0         Store   2014-12-26  1962-03-30   heidi76@example.org      Molly
# 1         Store   2020-11-27  1978-12-23  danaball@example.com       Alex
# 2         Store   2012-04-03  1984-01-06   dhunter@example.org       Mark
# 3         Store   2011-02-16  1967-06-02   donna15@example.net    Matthew
# 4           Web   2015-08-16  1995-01-11  drowland@example.net     Leslie
#
#   gender last_name state               street_address
# 0      F  Phillips    GA        083 Brandon Mountains
# 1      F    Acosta    FL          2484 Morrison Field
# 2      M      Hale    AL  5396 Jerry Island Suite 022
# 3      F   Perkins    MS    45358 Bryan Run Suite 919
# 4      M       Lee    MS           000 Cardenas Point

# %%
print(sql_queries.insert_customer_table)
# Out:
# INSERT INTO customers (first_name, last_name, email_address,
# dob, gender, street_address, state, date_created, create_source)
# VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)

# %%
### insert customer records
for i, row in df_customers.iterrows():
    if i % 100 == 0:
        print(i)
    db_conn.update(sql_queries.insert_customer_table, 
                        (row['first_name'],
                        row['last_name'],
                        row['email_address'],
                        row['dob'],
                        row['gender'],
                        row['street_address'],
                        row['state'],
                        row['date_created'],
                        row['create_source']))
# Out:
# 0
# duplicate key value violates unique constraint "customers_pkey"
# DETAIL:  Key (customer_id)=(2) already exists.
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# 100
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# 200
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# 300
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# 400
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# 500
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# ...
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# 900
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
#
# current transaction is aborted, commands ignored until end of transaction block
